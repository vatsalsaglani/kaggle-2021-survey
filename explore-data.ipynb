# %%
# !which python
# Out:
# /Users/vatsalsaglani/anaconda3/envs/data-analytics/bin/python

# %%
import os
import re
import pandas as pd
from utils import *

# %%
csv_data = pd.read_csv("data/kaggle_survey_2021_responses.csv")
# Out:
# /Users/vatsalsaglani/anaconda3/envs/data-analytics/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
csv_data.head(10)
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
# 5                                 781                        45-49
# 6                                1020                        25-29
# 7                                 141                        18-21
# 8                                 484                        30-34
# 9                                1744                        22-24
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# ...

# %%
question2text = csv_data.iloc[0].to_dict()
text2question = {v:k for k,v in question2text.items()}

# %%
# text2question["Duration (in seconds)"]

# %%
csv_data.drop(0, axis = 0, inplace = True)
csv_data.reset_index(inplace = True)

# %%
csv_data.head()
# Out:
#    index Time from Start to Finish (seconds)     Q1   Q2         Q3  \
# 0      1                                 910  50-54  Man      India
# 1      2                                 784  50-54  Man  Indonesia
# 2      3                                 924  22-24  Man   Pakistan
# 3      4                                 575  45-49  Man     Mexico
# 4      5                                 781  45-49  Man      India
#
#                   Q4                       Q5          Q6 Q7_Part_1 Q7_Part_2  \
# 0  Bachelor’s degree                    Other  5-10 years    Python         R
# 1    Master’s degree  Program/Project Manager   20+ years       NaN       NaN
# 2    Master’s degree        Software Engineer   1-3 years    Python       NaN
# 3    Doctoral degree       Research Scientist   20+ years    Python       NaN
# 4    Doctoral degree                    Other   < 1 years    Python       NaN
#
#    ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# ...

# %%
len(csv_data)
# Out:
# 25973

# %%
save_json(question2text, "data/question2text.json")
save_json(text2question, "data/text2question.json")

# %%
csv_data.to_csv("data/kaggle-survey-2021-edited.csv", index = False)
